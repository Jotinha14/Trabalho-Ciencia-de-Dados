# %%
import pandas as pd
import numpy as np

# %%
jvnq = pd.read_csv('vendas_modificado.csv')

# %%
jvnq.head()
# Out:
#    id_da_compra        data      hora                      cliente  \
# 0         13679  2021-03-20  23:35:51            LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53         MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28    FELIPE AUGUSTO NERY SILVA
# 3         20809  2022-06-04  08:41:23        LEVI RIBEIRO AMORIM
# 4         47123  2019-05-04  13:38:45  GABRIEL MATOS LIMA DA CUNHA
#
#             produto     valor  quantidade   total                status  \
# 0  Queijo Mussarela  R$ 16,87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   R$ 3,25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   R$ 1,63           9   36.67  Pagamento Confirmado
# 3            Carvão   R$ 8,74           4   54.96          Em Separação
# 4              Café   R$ 9,48           2   18.96          Em Separação
#
#                   cidade estado    pais        cep  frete  \
# 0                Niterói     RJ  Brasil  24000-000   20.0
# 1                Mariana     MG  Brasil  35420-000    0.0
# 2              Cabo Frio     RJ  Brasil  28900-000   22.0
# 3  Campos dos Goytacazes     RJ  Brasil  28000-000   20.0
# 4   Conselheiro Lafaiete     MG  Brasil  36400-000    0.0
#
#                 pagamento                            vendedor         marca
# 0       Cartão de Crédito             SAMUEL HENRIQUE CAÇADOR  Porto Alegre
# 1                     Pix  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini
# 2  Transferência Bancária         HENRICO MATOS LIMA DA CUNHA       Minalba
# 3                     Pix           GABRIEL QUEIROZ DE AGUIAR    Marca-Brás
# 4       Cartão de Crédito         HENRICO MATOS LIMA DA CUNHA    3 Corações

# %%
print(jvnq.dtypes)
# Out:
# id_da_compra      int64
# data             object
# hora             object
# cliente          object
# produto          object
# valor            object
# quantidade        int64
# total           float64
# status           object
# cidade           object
# estado           object
# pais             object
# cep              object
# frete           float64
# pagamento        object
# vendedor         object
# marca            object
# dtype: object

# %%
jvnq['data'] = pd.to_datetime(jvnq['data'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
jvnq['hora'] = pd.to_datetime(jvnq['hora'], format='%H:%M:%S', errors='coerce').dt.strftime('%H:%M:%S')

# %%
print(jvnq[['data', 'hora']].head())
# Out:
#          data      hora
# 0  2021-03-20  23:35:51
# 1  2020-10-30  09:00:53
# 2  2021-06-09  15:30:28
# 3  2022-06-04  08:41:23
# 4  2019-05-04  13:38:45

# %%
colunas_numericas = ['quantidade', 'total', 'frete']

for coluna in colunas_numericas:
    jvnq[coluna] = pd.to_numeric(jvnq[coluna], errors='coerce')


print(jvnq.dtypes)
# Out:
# id_da_compra      int64
# data             object
# hora             object
# cliente          object
# produto          object
# valor            object
# quantidade        int64
# total           float64
# status           object
# cidade           object
# estado           object
# pais             object
# cep              object
# frete           float64
# pagamento        object
# vendedor         object
# marca            object
# dtype: object

# %%
print(jvnq[['produto']].head())
# Out:
#             produto
# 0  Queijo Mussarela
# 1   Molho de Tomate
# 2      Água Mineral
# 3            Carvão
# 4              Café

# %%
import re

# %%
# Remover caracteres especiais da coluna 'produto'
jvnq['produto'] = jvnq['produto'].astype(str).apply(
    lambda x: re.sub(r'[^A-Za-z0-9À-ÿ\s]', '', x)
)

# %%
from fuzzywuzzy import process

produtos_unicos = jvnq['produto'].unique()
for prod in produtos_unicos:
    print(process.extract(prod, produtos_unicos, limit=3))
# Out:
# [('Queijo Mussarela', 100), ('Qbeijo Mussarela', 94), ('Queijo Mussarelz', 94)]
# [('Molho de Tomate', 100), ('Mopho de Tomate', 93), ('Molmo de Tomate', 93)]
# [('Água Mineral', 100), ('Água Mineras', 91), ('Água Mineual', 91)]
# [('Carvão', 100), ('Açúcar', 67), ('Macarrão', 67)]
# [('Café', 100), ('Caft', 86), ('Caff', 86)]
# [('Feijão', 100), ('ieijão', 80), ('Queijo Mussarela', 72)]
# [('Condicionador', 100), ('Condicioiador', 92), ('Condibionador', 92)]
# [('Sabonete', 100), ('zabonete', 88), ('Sabonepe', 88)]
# [('Açúcar', 100), ('Macarrão', 90), ('Açúcaz', 75)]
# [('Manteiga', 100), ('Manteigt', 88), ('Amaciante', 59)]
# [('Papel Higiênico', 100), ('Papel Toalha', 56), ('Papel qoalha', 56)]
# [('Óleo de Soja', 100), ('Pão de Forma', 64), ('Molho de Tomate', 62)]
# [('Vinho', 100), ('Papel Higiênico', 54), ('Farinha de Trigo', 54)]
# [('Macarrão', 100), ('Açúcar', 90), ('Macawrão', 86)]
# [('Shampoo', 100), ('Sal', 60), ('Sabão em Pó', 50)]
# [('Presunto', 100), ('Presuntd', 88), ('Papel Toalha', 45)]
# [('Cerveja', 100), ('Carvão', 50), ('Açúcar', 45)]
# [('Papel Toalha', 100), ('Papel qoalha', 92), ('Papel Twalha', 92)]
# [('Pasta de Dente', 100), ('Sal', 60), ('tal', 60)]
# [('Pão de Forma', 100), ('Mopho de Tomate', 69), ('Óleo de Soja', 64)]
# [('Sabão em Pó', 100), ('Sabonepe', 71), ('Sal', 60)]
# [('Amaciante', 100), ('Amaciayte', 89), ('Açúcar', 68)]
# [('Desinfetante', 100), ('Desinfetanue', 92), ('Desinfekante', 92)]
# [('Refrigerante', 100), ('Refrigkrante', 92), ('Detergente', 64)]
# [('Arroz', 100), ('Arroc', 80), ('Macarrão', 67)]
# [('Farinha de Trigo', 100), ('Farinha de Tripo', 94), ('Pão de Forma', 56)]
# [('Biscoito Recheado', 100), ('Biscoitq Recheado', 94), ('Scl', 60)]
# [('Sal', 100), ('Scl', 67), ('tal', 67)]
# [('Suco de Laranja', 100), ('Sucoyde Laranja', 93), ('Scl', 60)]
# [('Leite Integral', 100), ('Sal', 60), ('tal', 60)]
# [('Detergente', 100), ('Deqergente', 90), ('Deterwente', 90)]
# [('Refrigkrante', 100), ('Refrigerante', 92), ('Desinfekante', 58)]
# [('Scl', 100), ('Sal', 67), ('Clfé', 67)]
# [('Papel qoalha', 100), ('Papel Toalha', 92), ('Papel Twalha', 83)]
# [('Desinfetanue', 100), ('Desinfetante', 92), ('Desinfekante', 83)]
# [('Qbeijo Mussarela', 100), ('Queijo Mussarela', 94), ('Queijo Mussarelz', 88)]
# [('Água Mineras', 100), ('Água Mineral', 91), ('Água Mineual', 82)]
# [('Presuntd', 100), ('Presunto', 88), ('Pasta de Dente', 45)]
# [('Macawrão', 100), ('Macarrão', 86), ('Açúcar', 73)]
# [('Sucoyde Laranja', 100), ('Suco de Laranja', 93), ('Scl', 60)]
# [('Clfé', 100), ('Café', 67), ('Scl', 67)]
# [('Desinfekante', 100), ('Desinfetante', 92), ('Desinfetanue', 83)]
# [('Majarrão', 100), ('Macarrão', 86), ('Macawrão', 71)]
# [('Cnfé', 100), ('Café', 67), ('Clfé', 67)]
# [('Farinha de Tripo', 100), ('Farinha de Trigo', 94), ('Pão de Forma', 64)]
# [('Manteigt', 100), ('Manteiga', 88), ('Amaciante', 59)]
# [('zabonete', 100), ('Sabonete', 88), ('Sabonepe', 75)]
# [('Mqcarrão', 100), ('Macarrão', 86), ('Macawrão', 71)]
# [('Arroc', 100), ('Arroz', 80), ('Macarrão', 67)]
# [('tal', 100), ('Sal', 67), ('Água Mineral', 60)]
# [('Sabonepe', 100), ('Sabonete', 88), ('zabonete', 75)]
# [('Papel Twalha', 100), ('Papel Toalha', 92), ('Papel qoalha', 83)]
# [('Água Mineual', 100), ('Água Mineral', 91), ('Água Mineras', 82)]
# [('Condicioiador', 100), ('Condicionador', 92), ('Condibionador', 85)]
# [('Condibionador', 100), ('Condicionador', 92), ('Condicioiador', 85)]
# [('Caft', 100), ('Café', 86), ('Caff', 75)]
# [('ieijão', 100), ('Feijão', 80), ('Queijo Mussarela', 72)]
# [('Açúcaz', 100), ('Açúcar', 75), ('Macarrão', 68)]
# [('Amaciayte', 100), ('Amaciante', 89), ('Açúcar', 68)]
# [('Caff', 100), ('Café', 86), ('Caft', 75)]
# [('Mopho de Tomate', 100), ('Molho de Tomate', 93), ('Molmo de Tomate', 87)]
# [('Molmo de Tomate', 100), ('Molho de Tomate', 93), ('Mopho de Tomate', 87)]
# [('Biscoitq Recheado', 100), ('Biscoito Recheado', 94), ('Scl', 60)]
# [('Macirrão', 100), ('Macarrão', 86), ('Macawrão', 71)]
# [('Deqergente', 100), ('Detergente', 90), ('Deterwente', 80)]
# [('Cafc', 100), ('Café', 86), ('Caft', 75)]
# [('Queijo Mussarelz', 100), ('Queijo Mussarela', 94), ('Qbeijo Mussarela', 88)]
# [('Deterwente', 100), ('Detergente', 90), ('Deqergente', 80)]

# %%
correcao_produto = {
    "Qbeijo Mussarela": "Queijo Mussarela",
    "Queijo Mussarelz": "Queijo Mussarela",
    "Mopho de Tomate": "Molho de Tomate",
    "Água Mineras": "Água Mineral",
    "Água Mineual": "Água Mineral",
    "Condicioiador": "Condicionador",
    "Condibionador": "Condicionador",
    "zabonete": "Sabonete",
    "Sabonepe": "Sabonete",
    "Macawrão": "Macarrão",
    "Manteigt": "Manteiga",
    "Papel qoalha": "Papel Toalha",
    "Papel Twalha": "Papel Toalha",
    "Presuntd": "Presunto",
    "Amaciayte": "Amaciante",
    "Desinfetanue": "Desinfetante",
    "Desinfekante": "Desinfetante",
    "Refrigkrante": "Refrigerante",
    "Arroc": "Arroz",
    "Deqergente": "Detergente",
    "Deterwente": "Detergente",
    "Cafc": "Café",
    "Caft": "Café"
}
jvnq['produto'] = jvnq['produto'].replace(correcao_produto)

# %%
print(jvnq[['produto']].head())
# Out:
#             produto
# 0  Queijo Mussarela
# 1   Molho de Tomate
# 2      Água Mineral
# 3            Carvão
# 4              Café

# %%
print(jvnq.isnull().sum())
# Out:
# id_da_compra       0
# data               0
# hora               0
# cliente            0
# produto            0
# valor              0
# quantidade         0
# total           3685
# status             0
# cidade             0
# estado             0
# pais               0
# cep                0
# frete           7371
# pagamento          0
# vendedor        3680
# marca              0
# dtype: int64

# %%
jvnq['valor'] = jvnq['valor'].str.replace(r'R\$', '', regex=True).str.strip()

# %%
jvnq.head(3)
# Out:
#    id_da_compra        data      hora                    cliente  \
# 0         13679  2021-03-20  23:35:51          LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53       MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28  FELIPE AUGUSTO NERY SILVA
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16,87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3,25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1,63           9   36.67  Pagamento Confirmado
#
#       cidade estado    pais        cep  frete               pagamento  \
# 0    Niterói     RJ  Brasil  24000-000   20.0       Cartão de Crédito
# 1    Mariana     MG  Brasil  35420-000    0.0                     Pix
# 2  Cabo Frio     RJ  Brasil  28900-000   22.0  Transferência Bancária
#
#                              vendedor         marca
# 0             SAMUEL HENRIQUE CAÇADOR  Porto Alegre
# 1  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini
# 2         HENRICO MATOS LIMA DA CUNHA       Minalba

# %%
estado_correto = {
    'São Paulo': 'SP',
    'MTSa': 'MT',
    'PSC': 'SC'
}
jvnq['estado'] = jvnq['estado'].replace(estado_correto)

# %%
jvnq['Frete_Check1'] = jvnq.groupby(['cidade', 'estado'])['frete'].transform('median')

# %%
jvnq.head(3)
# Out:
#    id_da_compra        data      hora                    cliente  \
# 0         13679  2021-03-20  23:35:51          LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53       MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28  FELIPE AUGUSTO NERY SILVA
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16,87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3,25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1,63           9   36.67  Pagamento Confirmado
#
#       cidade estado    pais        cep  frete               pagamento  \
# 0    Niterói     RJ  Brasil  24000-000   20.0       Cartão de Crédito
# 1    Mariana     MG  Brasil  35420-000    0.0                     Pix
# 2  Cabo Frio     RJ  Brasil  28900-000   22.0  Transferência Bancária
#
#                              vendedor         marca  Frete_Check1
# 0             SAMUEL HENRIQUE CAÇADOR  Porto Alegre           0.0
# 1  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini           0.0
# 2         HENRICO MATOS LIMA DA CUNHA       Minalba          22.0

# %%
jvnq['Frete_Check2'] = jvnq.frete.fillna(jvnq.groupby (['cidade', 'estado'])['frete'].transform('median'))

# %%
jvnq = jvnq[(jvnq['frete'] >= 0) & (jvnq['total'] >= 0)]

# %%
jvnq.head(3)
# Out:
#    id_da_compra        data      hora                    cliente  \
# 0         13679  2021-03-20  23:35:51          LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53       MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28  FELIPE AUGUSTO NERY SILVA
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16,87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3,25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1,63           9   36.67  Pagamento Confirmado
#
#       cidade estado    pais        cep  frete               pagamento  \
# 0    Niterói     RJ  Brasil  24000-000   20.0       Cartão de Crédito
# 1    Mariana     MG  Brasil  35420-000    0.0                     Pix
# 2  Cabo Frio     RJ  Brasil  28900-000   22.0  Transferência Bancária
#
#                              vendedor         marca  Frete_Check1  \
# 0             SAMUEL HENRIQUE CAÇADOR  Porto Alegre           0.0
# 1  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini           0.0
# 2         HENRICO MATOS LIMA DA CUNHA       Minalba          22.0
#
#    Frete_Check2
# 0          20.0
# 1           0.0
# 2          22.0

# %%
jvnq['frete'] =   jvnq.frete.fillna(jvnq.groupby (['cidade', 'estado'])['frete'].transform('median'))

# %%
jvnq = jvnq.drop(columns=['Frete_Check1', 'Frete_Check2'])

# %%
jvnq.head(3)
# Out:
#    id_da_compra        data      hora                    cliente  \
# 0         13679  2021-03-20  23:35:51          LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53       MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28  FELIPE AUGUSTO NERY SILVA
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16,87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3,25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1,63           9   36.67  Pagamento Confirmado
#
#       cidade estado    pais        cep  frete               pagamento  \
# 0    Niterói     RJ  Brasil  24000-000   20.0       Cartão de Crédito
# 1    Mariana     MG  Brasil  35420-000    0.0                     Pix
# 2  Cabo Frio     RJ  Brasil  28900-000   22.0  Transferência Bancária
#
#                              vendedor         marca
# 0             SAMUEL HENRIQUE CAÇADOR  Porto Alegre
# 1  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini
# 2         HENRICO MATOS LIMA DA CUNHA       Minalba

# %%
print(jvnq.isnull().sum())
# Out:
# id_da_compra       0
# data               0
# hora               0
# cliente            0
# produto            0
# valor              0
# quantidade         0
# total              0
# status             0
# cidade             0
# estado             0
# pais               0
# cep                0
# frete              0
# pagamento          0
# vendedor        3518
# marca              0
# dtype: int64

# %%
def corrigir_valor(valor):
    match = re.search(r'\d{1,3}(,\d{2})?', str(valor))  
    if match:
        return match.group().replace(',', '.')
    return np.nan

jvnq['valor'] = jvnq['valor'].apply(corrigir_valor).astype(float)

# %%
# Calcular o total correto
jvnq['total_calculado'] = jvnq['valor'] * jvnq['quantidade'] + jvnq['frete']

# %%
jvnq[jvnq.total.isnull()].head(6)
# Out:
# Empty DataFrame
# Columns: [id_da_compra, data, hora, cliente, produto, valor, quantidade, total, status, cidade, estado, pais, cep, frete, pagamento, vendedor, marca, total_calculado]
# Index: []

# %%
jvnq['total'] = np.where(
    np.abs(jvnq['total'] - jvnq['total_calculado']) < 0.01,
    jvnq['total'],
    jvnq['total_calculado']
)

# %%
jvnq.drop(columns=['total_calculado'], inplace=True)

# %%
jvnq.head(6)
# Out:
#    id_da_compra        data      hora                      cliente  \
# 0         13679  2021-03-20  23:35:51            LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53         MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28    FELIPE AUGUSTO NERY SILVA
# 3         20809  2022-06-04  08:41:23        LEVI RIBEIRO AMORIM
# 4         47123  2019-05-04  13:38:45  GABRIEL MATOS LIMA DA CUNHA
# 5         38623  2018-02-19  17:32:01  LUCAS ANTÔNIO DE SOUZA NETO
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16.87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3.25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1.63           9   36.67  Pagamento Confirmado
# 3            Carvão   8.74           4   54.96          Em Separação
# 4              Café   9.48           2   18.96          Em Separação
# 5              Café  10.16           1   20.16  Entregue com Sucesso
#
#                   cidade estado    pais        cep  frete  \
# 0                Niterói     RJ  Brasil  24000-000   20.0
# 1                Mariana     MG  Brasil  35420-000    0.0
# 2              Cabo Frio     RJ  Brasil  28900-000   22.0
# 3  Campos dos Goytacazes     RJ  Brasil  28000-000   20.0
# 4   Conselheiro Lafaiete     MG  Brasil  36400-000    0.0
# 5          Resende Costa     MG  Brasil  36340-000   10.0
#
#                 pagamento                            vendedor         marca
# 0       Cartão de Crédito             SAMUEL HENRIQUE CAÇADOR  Porto Alegre
# 1                     Pix  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini
# 2  Transferência Bancária         HENRICO MATOS LIMA DA CUNHA       Minalba
# 3                     Pix           GABRIEL QUEIROZ DE AGUIAR    Marca-Brás
# 4       Cartão de Crédito         HENRICO MATOS LIMA DA CUNHA    3 Corações
# 5  Transferência Bancária           VICTOR GONÇALVES DONADONI    3 Corações

# %%
print(jvnq.isnull().sum())
# Out:
# id_da_compra       0
# data               0
# hora               0
# cliente            0
# produto            0
# valor              0
# quantidade         0
# total              0
# status             0
# cidade             0
# estado             0
# pais               0
# cep                0
# frete              0
# pagamento          0
# vendedor        3518
# marca              0
# dtype: int64

# %%
jvnq[jvnq.vendedor.isnull()].head(6)
# Out:
#      id_da_compra        data      hora                               cliente  \
# 112         52388  2018-07-30  07:10:51      MIGUEL ANTÔNIO DE DECCO OLIVEIRA
# 425         46034  2019-12-28  14:14:40  RAFAEL HENRIQUE COSTA BARNABE MARAZO
# 525         30444  2022-09-11  21:39:42              LUCAS GONÇALVES DONADONI
# 543         41142  2020-10-16  12:47:08               GABRIEL CARLOS DE SOUZA
# 544           194  2020-06-28  12:28:55                    MATEUS Araujo Kuhn
# 623         55288  2020-05-08  14:08:29               SAMUEL HENRIQUE CAÇADOR
#
#               produto   valor  quantidade    total                status  \
# 112          Manteiga    8.77           5    56.85  Pagamento Confirmado
# 425   Suco de Laranja  825.00           5  4125.00  Aguardando Pagamento
# 525              Café   10.33           2    20.66          Em Separação
# 543             Vinho   28.89           1    28.89  Pagamento Confirmado
# 544   Suco de Laranja    6.86           6    51.16          Em Separação
# 623  Queijo Mussarela   17.69           1    17.69              Entregue
#
#                     cidade estado    pais        cep  frete  \
# 112           Juiz de Fora     MG  Brasil  36000-000   13.0
# 425             Leopoldina     MG  Brasil   367XXXXX    0.0
# 525                Niterói     RJ  Brasil  24000-000   -0.0
# 543  Coronel Xavier Chaves     MG  Brasil  36330-000    0.0
# 544            Lima Duarte     MG  Brasil  36140-000   10.0
# 623                Niterói     RJ  Brasil  24000-000    0.0
#
#                   pagamento vendedor       marca
# 112       Cartão de Crédito      NaN     Aviação
# 425                  Boleto      NaN       Prats
# 525  Transferência Bancária      NaN  3 Corações
# 543       Cartão de Crédito      NaN       Miolo
# 544                     Pix      NaN       Prats
# 623  Transferência Bancária      NaN       Quatá

# %%
jvnq['vendedor'] = jvnq['vendedor'].fillna('DESCONHECIDO')

# %%
jvnq.head(6)
# Out:
#    id_da_compra        data      hora                      cliente  \
# 0         13679  2021-03-20  23:35:51            LUCAS Araujo Kuhn
# 1         28070  2020-10-30  09:00:53         MICAEL SOUZA RONCETE
# 2         47484  2021-06-09  15:30:28    FELIPE AUGUSTO NERY SILVA
# 3         20809  2022-06-04  08:41:23        LEVI RIBEIRO AMORIM
# 4         47123  2019-05-04  13:38:45  GABRIEL MATOS LIMA DA CUNHA
# 5         38623  2018-02-19  17:32:01  LUCAS ANTÔNIO DE SOUZA NETO
#
#             produto  valor  quantidade   total                status  \
# 0  Queijo Mussarela  16.87          13  239.31  Pagamento Confirmado
# 1   Molho de Tomate   3.25           3    9.75  Pagamento Confirmado
# 2      Água Mineral   1.63           9   36.67  Pagamento Confirmado
# 3            Carvão   8.74           4   54.96          Em Separação
# 4              Café   9.48           2   18.96          Em Separação
# 5              Café  10.16           1   20.16  Entregue com Sucesso
#
#                   cidade estado    pais        cep  frete  \
# 0                Niterói     RJ  Brasil  24000-000   20.0
# 1                Mariana     MG  Brasil  35420-000    0.0
# 2              Cabo Frio     RJ  Brasil  28900-000   22.0
# 3  Campos dos Goytacazes     RJ  Brasil  28000-000   20.0
# 4   Conselheiro Lafaiete     MG  Brasil  36400-000    0.0
# 5          Resende Costa     MG  Brasil  36340-000   10.0
#
#                 pagamento                            vendedor         marca
# 0       Cartão de Crédito             SAMUEL HENRIQUE CAÇADOR  Porto Alegre
# 1                     Pix  MICAEL MALAQUIAS DE SOUZA OLIVEIRA        Fugini
# 2  Transferência Bancária         HENRICO MATOS LIMA DA CUNHA       Minalba
# 3                     Pix           GABRIEL QUEIROZ DE AGUIAR    Marca-Brás
# 4       Cartão de Crédito         HENRICO MATOS LIMA DA CUNHA    3 Corações
# 5  Transferência Bancária           VICTOR GONÇALVES DONADONI    3 Corações

# %%
jvnq = jvnq.drop_duplicates()

# %%
status_correto = {
    'PC': 'Pagamento Confirmado',
    'Pgto Confirmado': 'Pagamento Confirmado',
    'AP': 'Aguardando Pagamento',
    'Aguardando Pgto': 'Aguardando Pagamento',
    'aguardando pagamento': 'Aguardando Pagamento',
    'Sep': 'Em Separação',
    'Separando': 'Em Separação',
    'Transp': 'Em Transporte',
    'Transportando': 'Em Transporte',
    'Entg': 'Entregue com Sucesso',
    'Entregue': 'Entregue com Sucesso'
}
jvnq['status'] = jvnq['status'].replace(status_correto)

# %%
for col in jvnq.select_dtypes(include='object').columns:
    jvnq[col] = jvnq[col].astype(str).str.strip()

# %%
jvnq = jvnq.drop_duplicates()

# %%
colunas_numericas = ['valor', 'quantidade', 'frete', 'total']
for col in colunas_numericas:
    if col in jvnq.columns:
        jvnq = jvnq[jvnq[col] >= 0]

# %%
if 'produto' in jvnq.columns:
    jvnq['produto'] = jvnq['produto'].astype(str).str.strip().str.lower()

# %%
jvnq = jvnq[
    (jvnq["valor"] >= 0) &
    (jvnq["quantidade"] >= 0) &
    (jvnq["frete"] >= 0) &
    (jvnq["total"] >= 0)
]

# %%
print(jvnq.isnull().sum())

print(jvnq[jvnq.isnull().any(axis=1)])
# Out:
# id_da_compra    0
# data            0
# hora            0
# cliente         0
# produto         0
# valor           0
# quantidade      0
# total           0
# status          0
# cidade          0
# estado          0
# pais            0
# cep             0
# frete           0
# pagamento       0
# vendedor        0
# marca           0
# dtype: int64
# Empty DataFrame
# Columns: [id_da_compra, data, hora, cliente, produto, valor, quantidade, total, status, cidade, estado, pais, cep, frete, pagamento, vendedor, marca]
# Index: []

# %%
jvnq = jvnq.dropna()

# %%
jvnq = jvnq.drop_duplicates(subset=['produto'])

# %%
mapeamento_produtos = {
    'produto a': 'produto a',
    'produto b': 'produto b'
}

jvnq['produto'] = jvnq['produto'].map(mapeamento_produtos).fillna(jvnq['produto'])

# %%
dados_faltantes = jvnq.isna().sum().sum()

# %%
linhas_com_nan = jvnq[jvnq.isnull().any(axis=1)]

# %%
valores_inconsistentes = {}
for col in ['valor', 'quantidade', 'frete', 'total']:
    if col in jvnq.columns:
        inconsistentes = jvnq[jvnq[col] <= 0]
        if not inconsistentes.empty:
            valores_inconsistentes[col] = inconsistentes

# %%
jvnq = jvnq[jvnq['produto'].str.match('^[A-Za-z0-9\s]+$')]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Magnolia\AppData\Local\Temp\ipykernel_16292\4281748892.py:1: SyntaxWarning: invalid escape sequence '\s'
#   jvnq = jvnq[jvnq['produto'].str.match('^[A-Za-z0-9\s]+$')]

# %%
valores_inconsistentes = jvnq[~jvnq['produto'].str.match('^[A-Za-z0-9\s]+$')].shape[0]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Magnolia\AppData\Local\Temp\ipykernel_16292\3541841481.py:1: SyntaxWarning: invalid escape sequence '\s'
#   valores_inconsistentes = jvnq[~jvnq['produto'].str.match('^[A-Za-z0-9\s]+$')].shape[0]

# %%
jvnq['produto'] = jvnq['produto'].replace('Produto@123', 'ProdutoCorreto')

# %%
produtos_unicos = jvnq['produto'].unique()

# %%
produtos_unicos = jvnq['produto'].astype(str).unique()
produtos_duplicados = jvnq['produto'].duplicated().sum()  
padronizacao_produtos = jvnq['produto'].str.lower().unique()

# %%
import unicodedata
jvnq['produto'] = jvnq['produto'].apply(lambda x: ''.join(c for c in unicodedata.normalize('NFD', x) if unicodedata.category(c) != 'Mn'))

# %%
produtos_unicos = jvnq['produto'].unique()

# %%
dados_faltantes = jvnq.isna().sum()  
total_faltante = jvnq.isna().sum().sum()

# %%
print(jvnq['produto'].unique())
# Out:
# ['queijo mussarela' 'molho de tomate' 'condicionador' 'sabonete'
#  'manteiga' 'vinho' 'shampoo' 'presunto' 'cerveja' 'papel toalha'
#  'pasta de dente' 'amaciante' 'desinfetante' 'refrigerante' 'arroz'
#  'farinha de trigo' 'biscoito recheado' 'sal' 'suco de laranja'
#  'leite integral' 'detergente' 'scl' 'sucoyde laranja' 'farinha de tripo'
#  'tal' 'caff' 'biscoitq recheado']

# %%
jvnq['produto'] = jvnq['produto'].astype(str).str.strip().str.lower()

# %%
jvnq = jvnq[jvnq['cep'].astype(str).str.match(r'^\d{5}-\d{3}$')]

# %%
for col in jvnq.select_dtypes(include='object').columns:
    jvnq[col] = jvnq[col].str.strip()

# %%
jvnq.to_csv('final_corrigido.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## <p align="center"><strong><span style="color:blue;">Relatório Resumido</span></strong></p>
#
# Etapas da Limpeza de Dados:
# Datas:
# Todas as datas foram padronizadas no formato internacional AAAA-MM-DD, facilitando a organização e a leitura dos registros.
#
# Horários:
# Os horários foram ajustados para o modelo de 24 horas, no formato HH:MM:SS, garantindo consistência nas análises envolvendo tempo.
#
# Valores Numéricos:
# As colunas com valores monetários e quantitativos como valor, quantidade, frete e total. Depois foram convertidas para tipos numéricos adequados (float ou int).
#
# Durante esse processo, foram removidos símbolos como “R$” e vírgulas, adotando o ponto (.) como separador decimal. Para facilitar essa limpeza, utilizamos expressões regulares com a biblioteca re.
#
# Tratamento de Dados Incompletos ou Duplicados:
# Campos Vazios
# Registros com informações essenciais faltando, como valor ou quantidade, foram removidos.
# Já os campos que não comprometem a integridade dos dados foram preenchidos com estratégias específicas. Por exemplo, o frete foi substituído pela média dos valores existentes, e datas ausentes foram preenchidas com o valor mais frequente (moda).
#
# Registros Duplicados:
# Também foi feita uma verificação de duplicatas. Um total de X registros repetidos foi identificado e excluído, priorizando sempre a versão mais completa ou mais recente.
#
# Correção do Campo "Total":
# Para garantir que os valores do campo total estavam corretos, aplicamos a fórmula-padrão:
#
# python
# Copiar
# Editar
# total = (valor * quantidade) + frete
# Quando identificamos divergências, os valores foram recalculados e atualizados com base nessa regra.
